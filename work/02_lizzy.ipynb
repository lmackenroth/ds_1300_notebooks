# %% [markdown]
# # Assignment: Working with Data

# %% [markdown]
# >Using the data below, answer the following questions:
#
# >1) Which entities (top 5) had the largest population density in 2020?
# >2) Which entities have more water area than land area?
# >3) Which entities increased in population the most in the last 10 years?
# >4) What state bird accounts for the largest population as of 2020? Land area?
# >5) How many entities' largest city is their capital city?
# >6) Which city has the largest percent drop from their largest city to their 5th largest? 100*(1st largest - 5th largest)/(1st largest)

# %%
import pandas as pd

# %%
pwd
# Out:
# '/users/lmackenroth/work'

# %%
facts = pd.read_csv('/users/lmackenroth/ds_1300_notebooks/data/state_facts.tsv',delimiter="\t")
facts.head(5)
# Out:
#               State  Area_tot  Area_land  Area_water   Pop_2020  Pop_2010  \
# 0          Alabama     135767     131171        4597  5024279.0   4779736
# 1           Alaska    1723337    1477953      245384   733391.0    710231
# 2   American Samoa       1505        198        1307    49437.0     55519
# 3          Arizona     295234     294207        1026  7151502.0   6392017
# 4         Arkansas     137732     134771        2961  3011524.0   2915918
#
#   Rep_seats                        State_bird             State_flower  \
# 0         7  Yellowhammer (Northern flicker)                  Camellia
# 1         1                 Willow ptarmigan            Forget-me-not
# 2       1*                               None         Paogo (Ulafala)
# 3         9                      Cactus wren   Saguaro cactus blossom
# 4         4             Northern mockingbird            Apple blossom
#
#                       State_motto  ...        City_1 city_1_pop       City_2  \
# ...

# %% [markdown]
# **Question 1: Which entities (top 5) had the largest population density in 2020?**

# %%
Pop_2020_top = facts.sort_values(by='Pop_2020',ascending=False)
Pop_2020_top.head()
# Out:
#              State  Area_tot  Area_land  Area_water    Pop_2020  Pop_2010  \
# 5      California     423967     403466       20501  39538223.0  37253956
# 47          Texas     695662     676587       19075  29145505.0  25145561
# 10        Florida     170312     138887       31424  21538187.0  18801310
# 34       New York     141297     122057       19240  20201249.0  19378102
# 41   Pennsylvania     119280     115883        3397  13002700.0  12702379
#
#    Rep_seats             State_bird       State_flower  \
# 5         52      California quail   California poppy
# 47        38  Northern mockingbird     Bluebonnet sp.
# 10        28  Northern mockingbird      Orange blossom
# 34        26      Eastern bluebird               Rose
# 41        17         Ruffed Grouse     Mountain laurel
#
#                           State_motto  ...          City_1 city_1_pop  \
# 5                             Eureka   ...    Los Angeles     3997984
# ...

# %% [markdown]
# **California, Texas, Florida, New York, Pennsylvania**

# %% [markdown]
# **Question 2: Which entities have more water area than land area?**

# %%
facts['water-land'] = facts['Area_water'] -  facts['Area_land']  
top_watervland = facts.sort_values(by='water-land',ascending=False)
top_watervland.head()
# Out:
#                              State  Area_tot  Area_land  Area_water  Pop_2020  \
# 37       Northern Mariana Islands       5117        472        4644      51.0
# 48   United States Virgin Islands       1898        348        1550  106235.0
# 2                  American Samoa       1505        198        1307   49437.0
# 12                           Guam       1478        543         935     168.4
# 9            District of Columbia        177        158          19  689545.0
#
#     Pop_2010 Rep_seats           State_bird                State_flower  \
# 37     53883       1*   Mariana fruit-dove                 Flores mayo
# 48    106405       1*      California gull                Yellow Elder
# 2      55519       1*                  None            Paogo (Ulafala)
# 12    159358       1*   Guam rail (ko'ko')   Bougainvillea spectabilis
# 9     601723       1*          Wood thrush        American Beauty Rose
#
# ...

# %% [markdown]
# **Northern Mariana Islands, United States Virgin Islands, American Samoa, Guam**

# %% [markdown]
# **Question 3: Which entities increased in population the most in the last 10 years?**

# %%
facts['state_increase'] = facts['Pop_2020'] -  facts['Pop_2010'] 
top_state = facts.sort_values(by='state_increase',ascending=False)
top_state.head()
# Out:
#            State  Area_tot  Area_land  Area_water    Pop_2020  Pop_2010  \
# 47        Texas     695662     676587       19075  29145505.0  25145561
# 10      Florida     170312     138887       31424  21538187.0  18801310
# 5    California     423967     403466       20501  39538223.0  37253956
# 11      Georgia     153910     148959        4951  10711908.0   9687653
# 52   Washington     184661     172119       12542   7705281.0   6724540
#
#    Rep_seats                              State_bird         State_flower  \
# 47        38                   Northern mockingbird       Bluebonnet sp.
# 10        28                   Northern mockingbird        Orange blossom
# 5         52                       California quail     California poppy
# 11        14                         Brown thrasher         Cherokee rose
# 52        10  Willow goldfinch (American goldfinch)   Coast rhododendron
#
#                      State_motto  ...        City_2 city_2_pop     City_3  \
# ...

# %% [markdown]
# **Question 4: What state bird accounts for the largest population as of 2020? Land area?**

# %% [markdown]
# **California quail** - State bird from state with largest population (California)

# %%
top_land = facts.sort_values(by='Area_land',ascending=False)
top_land.head(1)
# Out:
#       State  Area_tot  Area_land  Area_water  Pop_2020  Pop_2010 Rep_seats  \
# 1   Alaska    1723337    1477953      245384  733391.0    710231         1
#
#           State_bird    State_flower           State_motto  ...   City_2  \
# 1  Willow ptarmigan   Forget-me-not   North to the Future   ...  Juneau
#
#   city_2_pop      City_3  city_3_pop    City_4  city_4_pop  City_5  \
# 1    32113.0  Fairbanks      31516.0  Wasilla      10529.0  Sitka
#
#    city_5_pop water-land  state_increase
# 1      8647.0   -1232569         23160.0
#
# [1 rows x 28 columns]

# %% [markdown]
# **Willow ptarmigan** - State bird from state with largest land Mass(alaska)

# %% [markdown]
# **Question 5: How many entities' largest city is their capital city?**

# %%
facts[(facts['City_1'] == facts['Capital'])].head()
#used .count()
# Out:
#                      State  Area_tot  Area_land  Area_water    Pop_2020  \
# 3                 Arizona     295234     294207        1026   7151502.0
# 4                Arkansas     137732     134771        2961   3011524.0
# 6                Colorado     269601     268431        1170   5773714.0
# 9    District of Columbia        177        158          19    689545.0
# 11                Georgia     153910     148959        4951  10711908.0
#
#     Pop_2010 Rep_seats             State_bird               State_flower  \
# 3    6392017         9           Cactus wren     Saguaro cactus blossom
# 4    2915918         4  Northern mockingbird              Apple blossom
# 6    5029196         8          Lark bunting   Rocky Mountain columbine
# 9     601723       1*            Wood thrush       American Beauty Rose
# 11   9687653        14        Brown thrasher               Cherokee rose
#
#                      State_motto  ... city_2_pop         City_3  city_3_pop  \
# ...

# %% [markdown]
# **17**

# %% [markdown]
# **Question 6: Which city has the largest percent drop from their largest city to their 5th largest? 100(1st largest - 5th largest)/(1st largest**

# %%
facts['drop'] = 100*(facts['city_1_pop'] - facts['city_5_pop'])/(facts['city_1_pop'])
top_drop = facts.sort_values(by='drop',ascending=False)
top_drop.head()
# Out:
#              State  Area_tot  Area_land  Area_water    Pop_2020  Pop_2010  \
# 34       New York     141297     122057       19240  20201249.0  19378102
# 1          Alaska    1723337    1477953      245384    733391.0    710231
# 15       Illinois     149995     143793        6202  12812508.0  12830632
# 41   Pennsylvania     119280     115883        3397  13002700.0  12702379
# 19       Kentucky     104656     102269        2387   4505836.0   4339367
#
#    Rep_seats          State_bird     State_flower  \
# 34        26   Eastern bluebird             Rose
# 1          1   Willow ptarmigan    Forget-me-not
# 15        17  Northern cardinal            Violet
# 41        17      Ruffed Grouse   Mountain laurel
# 19         6  Northern cardinal        Goldenrod
#
#                                           State_motto  ... city_2_pop  \
# 34                                        Excelsior!   ...   251298.0
# 1                                North to the Future   ...    32113.0
# ...

# %% [markdown]
# **New york has the biggest population drop**

# %% [markdown]
# >Using the "state_dates.tsv" data, answer the remaining questions. You will need to merge the two data sets together:
#
# >7) Of the states that joined the United States before 1790, what is the most common state flower?
# >8) Which has the larger population density, the most dense US Territory or the least dense state?
# >9) Make a graph that plots the populations of the largest city in each entity in the order in which they joined the US. Make the bars black
# >10) Make two additional graphs like the one above but one for land area (green bars) and one for water area (blue bars)

# %%
more = pd.read_csv('/users/lmackenroth/ds_1300_notebooks/data/state_dates.tsv',delimiter="\t")

# %%
more['Date_Fixed'] = pd.to_datetime(more['Date'],errors='raise')
more[['Date','Date_Fixed']].head()
# Out:
#                 Date Date_Fixed
# 0  December 14, 1819 1819-12-14
# 1    January 3, 1959 1959-01-03
# 2     April 17, 1900 1900-04-17
# 3  February 14, 1912 1912-02-14
# 4      June 15, 1836 1836-06-15

# %%
more.drop('Date', inplace = True, axis=1)
more.head()
# Out:
#              Name     Status Abbreviation Date_Fixed
# 0        Alabama       State          AL  1819-12-14
# 1         Alaska       State          AK  1959-01-03
# 2  American Samoa  Territory           AS 1900-04-17
# 3        Arizona       State          AZ  1912-02-14
# 4       Arkansas       State          AR  1836-06-15

# %%
new = pd.merge(facts,more,left_on='USPS_code',right_on='Abbreviation',how='outer').drop(columns=['Name'])
new.head()
# Out:
#               State  Area_tot  Area_land  Area_water   Pop_2020  Pop_2010  \
# 0          Alabama     135767     131171        4597  5024279.0   4779736
# 1           Alaska    1723337    1477953      245384   733391.0    710231
# 2   American Samoa       1505        198        1307    49437.0     55519
# 3          Arizona     295234     294207        1026  7151502.0   6392017
# 4         Arkansas     137732     134771        2961  3011524.0   2915918
#
#   Rep_seats                        State_bird             State_flower  \
# 0         7  Yellowhammer (Northern flicker)                  Camellia
# 1         1                 Willow ptarmigan            Forget-me-not
# 2       1*                               None         Paogo (Ulafala)
# 3         9                      Cactus wren   Saguaro cactus blossom
# 4         4             Northern mockingbird            Apple blossom
#
#                       State_motto  ...       City_4 city_4_pop       City_5  \
# ...

# %% [markdown]
# **Question 7: Of the states that joined the United States before 1790, what is the most common state flower?**

# %%
#from datetime import datetime
#date = datetime.strptime(new['Date_Fixed'], '%Y-%m-%d')
    
colonies = new[new['Date_Fixed']<pd.datetime(1790,1,1)]
colonies.head()
# Out:
# /tmp/ipykernel_1587559/4227418670.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   colonies = new[new['Date_Fixed']<pd.datetime(1790,1,1)]
#               State  Area_tot  Area_land  Area_water    Pop_2020  Pop_2010  \
# 7      Connecticut      14357      12542        1816   3605944.0   3574097
# 8         Delaware       6446       5047        1399    989948.0    897934
# 11         Georgia     153910     148959        4951  10711908.0   9687653
# 22        Maryland      32131      25142        6990   6177224.0   5773552
# 23   Massachusetts      27336      20202        7134   7029917.0   6547629
#
#    Rep_seats               State_bird       State_flower  \
# 7          5          American robin     Mountain laurel
# 8          1       Delaware Blue Hen      Peach blossom
# 11        14          Brown thrasher       Cherokee rose
# ...

# %%
colonies['State_flower'].value_counts()
# Out:
# Mountain laurel      2
# Peach blossom        1
# Cherokee rose        1
# Black-eyed susan     1
# Mayflower            1
# Purple lilac         1
# Violet               1
# Rose                 1
# Flowering dogwood    1
# Yellow jessamine     1
# American dogwood     1
# Name: State_flower, dtype: int64

# %% [markdown]
# **common flower: Mountain laurel**

# %% [markdown]
# **Question 8:

# %%
new['population_density'] = new['Pop_2020'] / new['Area_land']
#dense= new.sort_values(by='population_density', ascending=False)
#stat= dense.sort_values( by = 'Status',ascending=False)

#stat = status.groupby(by = 'Status')
new.head(10)
# Out:
#                     State  Area_tot  Area_land  Area_water    Pop_2020  \
# 0                Alabama     135767     131171        4597   5024279.0
# 1                 Alaska    1723337    1477953      245384    733391.0
# 2         American Samoa       1505        198        1307     49437.0
# 3                Arizona     295234     294207        1026   7151502.0
# 4               Arkansas     137732     134771        2961   3011524.0
# 5             California     423967     403466       20501  39538223.0
# 6               Colorado     269601     268431        1170   5773714.0
# 7            Connecticut      14357      12542        1816   3605944.0
# 8               Delaware       6446       5047        1399    989948.0
# 9   District of Columbia        177        158          19    689545.0
#
#    Pop_2010 Rep_seats                        State_bird  \
# 0   4779736         7  Yellowhammer (Northern flicker)
# 1    710231         1                 Willow ptarmigan
# ...

# %%
max_ter = new['population_density'][new['Status']=='Territory'].max()
max_ter
# Out:
# 370.5315741993685

# %%
min_stat = new['population_density'][new['Status']=='State'].min()
min_stat
# Out:
# 0.49622078645261386

# %% [markdown]
# Hint: `pd.read_csv('../data/state_dates.tsv',delimiter="\t")`
#
# Hint: You likely want to convert the Date column to datetime. You might have to correct errors in the data as well.
#
# Hint: `states['Date']<pd.datetime(1790,1,1)`
#
# Hint: `pd.merge(****,****,left_on='USPS_code',right_on='Abbreviation',how='outer')`

# %%
dates_sorted = new.sort_values(by='Date_Fixed',ascending=True)

# %%
# Sample code to help with the plots

import matplotlib as plt
# %config InlineBackend.figure_format ='retina' #This makes your plot clearer


plot = dates_sorted[['Pop_2020','City_1']].plot(kind='bar',figsize=(10,4), color = 'black')
plot.set_xticklabels(dates_sorted['City_1']);

# %%
plot = dates_sorted[['Area_land','State']].plot(kind='bar',figsize=(10,4), color = 'green')
plot.set_xticklabels(dates_sorted['State']);

# %%
plot = dates_sorted[['Area_water','State']].plot(kind='bar',figsize=(10,4), color = 'blue')
plot.set_xticklabels(dates_sorted['State']);
